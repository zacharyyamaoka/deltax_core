# %%
import numpy as np

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
e = 120

d = e * 0.5 * np.tan(np.deg2rad(30))

print(round(d,3), "mm")
print(round(d/1000,6), "m")
# Out:
# 34.641 mm
# 0.035 m
